# %% [markdown]
# Seaborn 익히기

# %%
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

flights1 = sns.load_dataset('flights')
flights2 = sns.load_dataset('flights')
plt.figure(figsize=(12,3))
"""
sns.barplot(data=flights1, x='year', y='passengers')

sns.boxplot(data=flights1, x='year', y='passengers')

sns.violinplot(data=flights1, x='year', y='passengers')

sns.swarmplot(data=flights1, x='year', y='passengers')
"""

sns.lineplot(data=flights2, x='year', y='passengers')
sns.displot(data=flights2, x='year', y='passengers')
#sns.histplot(data=flights2, x='year', y='passengers')
